# %%
number_list = [0,1,4,13,15,12,16]

# %%
vals = {v: p for v, p in zip(number_list, range(1,len(number_list)))}
vals
# Out:
# {0: 1, 1: 2, 4: 3, 13: 4, 15: 5, 12: 6}

# %%
for pos in range(7,30000000): # current and next
    
    cur = number_list[-1]
    checkin = cur in vals
    
    # first dict
    if checkin is True:
        org_pos = vals[cur]
        vals[cur] = pos
    else:
        vals[cur] = pos
        
    # select next
    if checkin is True:
        nex = pos - org_pos
    else:
        nex = 0
            
    number_list.append(nex)

# %%
vals
# Out:
# {0: 2016,
#  1: 2012,
#  4: 2005,
#  13: 1971,
#  15: 1960,
#  12: 1932,
#  16: 1834,
#  7: 2017,
#  2: 1934,
#  11: 1987,
#  3: 1577,
#  21: 1621,
#  5: 1997,
#  17: 1920,
#  30: 1405,
#  10: 1958,
#  22: 1999,
#  19: 2006,
#  40: 1708,
#  6: 2018,
#  47: 1943,
#  14: 2013,
#  26: 1798,
#  38: 1391,
#  9: 1966,
#  27: 1887,
#  85: 1291,
#  72: 1939,
#  20: 1762,
#  34: 1807,
#  24: 1907,
#  8: 1982,
#  58: 1992,
#  106: 124,
#  32: 1782,
#  109: 603,
#  33: 1962,
#  37: 1585,
#  29: 1861,
#  112: 151,
#  36: 1915,
#  71: 323,
#  111: 1641,
#  98: 581,
#  49: 742,
#  18: 1879,
#  90: 716,
#  50: 2004,
#  110: 1311,
#  120: 1460,
#  23: 1812,
#  52: 1883,
#  60: 970,
#  28: 1977,
#  63: 1755,
#  56: 1673,
#  68: 1591,
#  31: 1935,
#  41: 1819,
#  76: 978,
#  80: 1523,
#  75: 934,
#  228: 262,
#  59: 1166,
#  141: 269,
#  53: 1855,
#  135: 279,
#  239: 1868,
#  192: 289,
#  48: 1479,
#  54: 1767,
#  207: 305,
#  105: 1978,
#  62: 1709,
#  170: 319,
#  164: 324,
#  66: 1571,
# ...

# %%
number_list
# Out:
# [0,
#  1,
#  4,
#  13,
#  15,
#  12,
#  16,
#  0,
#  7,
#  0,
#  2,
#  0,
#  2,
#  2,
#  1,
#  13,
#  12,
#  11,
#  0,
#  7,
#  11,
#  3,
#  0,
#  4,
#  21,
#  0,
#  3,
#  5,
#  0,
#  3,
#  3,
#  1,
#  17,
#  0,
#  5,
#  7,
#  16,
#  30,
#  0,
#  5,
#  5,
#  1,
#  10,
#  0,
#  5,
#  4,
#  22,
#  0,
#  4,
#  3,
#  19,
#  0,
#  4,
#  4,
#  1,
#  13,
#  40,
#  0,
#  6,
#  0,
#  2,
#  47,
#  0,
#  3,
#  14,
#  0,
#  3,
#  3,
#  1,
#  14,
#  5,
#  26,
#  0,
#  7,
#  38,
#  0,
#  3,
#  9,
#  0,
#  3,
#  3,
#  1,
#  13,
#  27,
#  0,
#  6,
#  27,
#  3,
#  7,
#  15,
#  85,
#  0,
#  7,
#  4,
#  40,
#  38,
#  21,
#  72,
#  0,
#  7,
#  7,
#  1,
#  20,
#  0,
#  5,
#  34,
#  0,
#  3,
#  20,
#  6,
#  24,
#  0,
#  5,
#  8,
#  0,
#  3,
#  8,
#  3,
#  2,
#  58,
#  0,
#  6,
#  12,
#  106,
#  0,
#  4,
#  32,
#  0,
#  3,
#  11,
#  109,
#  0,
#  4,
#  7,
#  33,
#  0,
#  4,
#  4,
#  1,
#  37,
#  0,
#  5,
#  29,
#  0,
#  3,
#  16,
#  109,
#  16,
#  2,
#  30,
#  112,
#  0,
#  8,
#  36,
#  0,
#  3,
#  11,
# ...

# %%
number_list[29999999]
# Out:
# 16439

# %%
# 0360331040
